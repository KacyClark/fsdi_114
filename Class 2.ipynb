# %% [markdown]
# Anagram "I am Lord Voldermort and Tom Marvolo Ripple"
#
# def anagram (string_a, string_b):
#    first_word = str(string_a).lower().replace(" ", "")
#    second_word = str(string_b).lower().replace(" ", "")
#    if len(first_word) == len(second_word):
#        count = 0
#        for a in first_word:
#            for b in second_word:
#                if (a == b):
#                    count += 1
#        if (len(first_word) == count and len(second_word) == count:
#            print("True. They are anagrams")
#            else:
#                print("False. They are not anagrams.")
#    else:
#        print("False. They are not anagrams.")
#
# anagrams("I am Lord Voldermort", "Tom Marvolo Riddle")

# %% [markdown]
# This is an example of a stack using built-in data structures
#
# class Stack:
#     def __init__(self):
#         self.base = None
#
#     def push(self, item):
#         if not self.base:
#             self.base = Node(item)
#         else:
#             self.base = current
#             while current.above:  #while current.above != None
#                 current = current.above
#             current.above = Node(item)
#
#     def pop(self):
#         return self.items.pop()
#
#     def is_empty(self):
#         if not self.base:
#             return True
#         return False
#
#     def size(self):
#         return len(self.items)
#
#     def peek(self):
#         return self.items[len(self.items)-1]
#
#      Problem 2: Invert a string
#      ### Stacks naturally allow for us to invert a sequence of elements if we sequentially push them onto our stack and sequentially pop them from our stack
#      #### Use our stack class above to invert a string such that:
#      reverse ("Rafael") returns "leafaR"
#      reverse ("racecar") returns "racecar"
#      reverse ("AbCdE") returns "EdCbA"
#
#      def reverse(mystring):
#          stack = Stack()
#          reversed = ""
#          out = ""
#          for letter in mystring:
#              print("Adding %s to our stack" % letter)
#              stack.push(letter)
#              while stack.is_empty() !=True:
#                  char = stack.pop()
#                  print("Adding %s to our output string" % char)
#                  out = out + char
#              return out
#
#
# class Queue:
#     def __init__(self):
#         self.items = []
#
#     def enqueue(self):
#         self.items.insert(0, item)
#
#     def dequeue(self):
#         return self.items.pop()
#
#     def is_empty(self):
#         return self.items == []
#
#     def size(self):
#         return len(self, items)

# %%
from random import randint
from time import sleep


def square_queue(elements):
    queue = Queue()
    for element in elements:
        print("Adding %s to our queue." % element)
        queue.enqueue(element)
    while not queue.is_empty():
        datum = queue.dequeue()
        sleep(randint(1, 3))
        print("%s squared is %s" % (datum, datum **2))
        
    square_queue([1, 2, 3, 4, 5])
